# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AhsanullahCS/FlyRank_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane
#
# I selected the "Structured Content Archetype Clustering" lane because I want to discover different types of webpage performance in the dataset. By grouping similar pages together, I can identify high-performing pages, underperforming pages, and pages with improvement opportunities. These insights can help content and SEO teams make better decisions based on data instead of manual inspection.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Decision
#
# This project helps identify groups of webpages with similar performance so that the SEO and content teams can decide which pages need optimization, monitoring, or can be used as successful examples.
#
# ### Action
#
# The SEO and content teams will review the cluster profiles and take actions such as improving low-performing pages, updating content, or maintaining high-performing pages.
#
# ### Cost of a Wrong Recommendation
#
# If pages are assigned to the wrong cluster, teams may spend time improving pages that are already performing well while ignoring pages that actually need attention. This could reduce the effectiveness of SEO efforts and waste time and resources.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("ss.csv")

df.head()
print("Rows and Columns:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# Rows and Columns: (10, 5)
#
# Missing Values:
# Page           0
# Clicks         0
# Impressions    0
# CTR            0
# Position       0
# dtype: int64
#
# Summary Statistics:
#             Clicks   Impressions        CTR   Position
# count    10.000000     10.000000  10.000000  10.000000
# mean    540.000000  10030.000000   5.480000   6.760000
# std     370.285175   5201.292574   2.257727   3.913566
# min     100.000000   1800.000000   2.300000   1.800000
# 25%     262.500000   7500.000000   3.650000   4.000000
# 50%     450.000000  10500.000000   5.300000   6.200000
# 75%     812.500000  13500.000000   6.825000   9.400000
# max    1200.000000  18000.000000   9.500000  13.500000

# %% [markdown]
# ### What my work can claim
#
# This project will identify groups of webpages with similar performance characteristics based on the available data. The discovered clusters can help the SEO and content teams understand common performance patterns and support decisions about which pages may need optimization, monitoring, or further investigation.
#
# ### What my work cannot claim
#
# This project cannot prove that one factor causes better search performance or predict Google's ranking algorithm. The results are intended to provide decision support based on observed patterns in the available dataset, not causal proof or guaranteed future outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
